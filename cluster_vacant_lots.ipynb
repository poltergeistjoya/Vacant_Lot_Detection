# %%
from config import load_config
from gee_utils import init_gee

# %%
CONFIG_PATH = "config.yaml"
CONFIG = load_config(CONFIG_PATH)
# Out:
# 01:06:01 | INFO | vacant_lots | YAML loaded

# %%
init_gee(CONFIG.EARTH_ENGINE)
# Out:
# 01:06:03 | INFO | vacant_lots | Initializing GEE with ADC credentials and project:vacant-lot-detection
# 01:06:03 | INFO | vacant_lots | GEE sucessfully initialized

# %%
import ee


print(ee.Image("CGIAR/SRTM90_V4").getInfo()["id"])
# Out:
# CGIAR/SRTM90_V4
